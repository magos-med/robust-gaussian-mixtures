# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_blobs
import plotly.express as px
import plotly.io as pio

from clustering import StandardGaussianMixture, SpearmanGaussianMixture, MADSpearmanGaussianMixture, MADApproxOrtizGaussianMixture, MADOrtizGaussianMixture
from utils import plot_gaussian_mixtures

pio.templates.default = 'ggplot2'
# pio.renderers.default = "svg"

# %%
# Create a dataset of 2D distributions
n_clusters = 3
x_train, true_labels = make_blobs(n_samples=100, centers=n_clusters, random_state=42, center_box=[-10, 10])
x_train_scaled = StandardScaler().fit_transform(x_train)

# %%
px.scatter(x=x_train_scaled[:, 0], y=x_train_scaled[:, 1], color=true_labels)

# %%
gmm = StandardGaussianMixture(n_components=n_clusters)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 1.0

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
gmm = SpearmanGaussianMixture(n_components=n_clusters, max_iter=100)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 1.0

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
gmm = MADApproxOrtizGaussianMixture(n_components=n_clusters, max_iter=100)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.6764705882352942

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
noise, noise_labels = make_blobs(n_samples=2, centers=[[100, 1]])
x_train = np.append(x_train, noise, axis=0)
true_labels = np.append(true_labels, noise_labels)
x_train_scaled = StandardScaler().fit_transform(x_train)

# %%
px.scatter(x=x_train_scaled[:, 0], y=x_train_scaled[:, 1], color=true_labels)

# %%
gmm = StandardGaussianMixture(n_components=n_clusters)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.6764705882352942

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
gmm = MADSpearmanGaussianMixture(n_components=n_clusters, max_iter=100)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 1.0

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
gmm = MADOrtizGaussianMixture(n_components=n_clusters, max_iter=100)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.6764705882352942

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
gmm = MADApproxOrtizGaussianMixture(n_components=n_clusters, max_iter=100)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.6764705882352942

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %% [markdown]
# # Outlier no tan abrupto

# %%
n_clusters = 3
x_train, true_labels = make_blobs(n_samples=100, centers=n_clusters, random_state=42, center_box=[-10, 10])
x_train_scaled = StandardScaler().fit_transform(x_train)

# %%
gmm = MADApproxOrtizGaussianMixture(n_components=n_clusters, max_iter=100)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.6764705882352942

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
noise, noise_labels = make_blobs(n_samples=2, centers=[[20, 1]])
x_train = np.append(x_train, noise, axis=0)
true_labels = np.append(true_labels, noise_labels)
x_train_scaled = StandardScaler().fit_transform(x_train)

# %%
px.scatter(x=x_train_scaled[:, 0], y=x_train_scaled[:, 1], color=true_labels)

# %%
gmm = StandardGaussianMixture(n_components=n_clusters)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
gmm = SpearmanGaussianMixture(n_components=n_clusters, max_iter=100)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
gmm = MADSpearmanGaussianMixture(n_components=n_clusters, max_iter=100)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
gmm = MADApproxOrtizGaussianMixture(n_components=n_clusters, max_iter=100)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.9803921568627451

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %% [markdown]
# # Clusters más juntos

# %%
n_clusters = 3
x_train, true_labels = make_blobs(n_samples=100, centers=n_clusters, random_state=42, center_box=[-5, 5])
x_train_scaled = StandardScaler().fit_transform(x_train)

# %%
gmm = MADApproxOrtizGaussianMixture(n_components=n_clusters, max_iter=100)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.6764705882352942

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
noise, noise_labels = make_blobs(n_samples=2, centers=[[20, 1]])
x_train = np.append(x_train, noise, axis=0)
true_labels = np.append(true_labels, noise_labels)
x_train_scaled = StandardScaler().fit_transform(x_train)

# %%
px.scatter(x=x_train_scaled[:, 0], y=x_train_scaled[:, 1], color=true_labels)

# %%
gmm = StandardGaussianMixture(n_components=n_clusters)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
gmm = SpearmanGaussianMixture(n_components=n_clusters, max_iter=100)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.6764705882352942

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)
# Out:
# <div>                            <div id="adf3fd7e-dcd7-4e15-bbfe-4304205e3e1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("adf3fd7e-dcd7-4e15-bbfe-4304205e3e1e")) {                    Plotly.newPlot(                        "adf3fd7e-dcd7-4e15-bbfe-4304205e3e1e",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"black","symbol":"x-thin","line":{"width":2},"size":12},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.2045315844998852,-0.6921196103840315,5.46432364146754],"xaxis":"x","y":[0.6339877688261637,-1.1815331778673637,0.07122982043733195],"yaxis":"y","type":"scatter"},{"fill":"toself","fillcolor":"rgb(55.0, 111.5, 155.0)","legendgroup":"ellipses","mode":"none
# ...

# %%
gmm = MADApproxOrtizGaussianMixture(n_components=n_clusters, max_iter=100)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.9607843137254902

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)
# Out:
# <div>                            <div id="456237fd-c3d9-414d-9574-7fde7d790b1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("456237fd-c3d9-414d-9574-7fde7d790b1f")) {                    Plotly.newPlot(                        "456237fd-c3d9-414d-9574-7fde7d790b1f",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"black","symbol":"x-thin","line":{"width":2},"size":12},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1.0107545204972197,-0.7755355899939483,-0.21473933023410255],"xaxis":"x","y":[0.05264693503204768,-1.2253028545170623,1.0742026845251653],"yaxis":"y","type":"scatter"},{"fill":"toself","fillcolor":"rgb(55.0, 111.5, 155.0)","legendgroup":"ellipses","mode":"
# ...

# %% [markdown]
# # Aún más juntos

# %%
n_clusters = 3
x_train, true_labels = make_blobs(n_samples=100, centers=n_clusters, random_state=42, center_box=[-2.5, 2.5])
x_train_scaled = StandardScaler().fit_transform(x_train)

# %%
gmm = StandardGaussianMixture(n_components=n_clusters)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.88

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
gmm = SpearmanGaussianMixture(n_components=n_clusters, max_iter=100)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.89

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
gmm = MADApproxOrtizGaussianMixture(n_components=n_clusters, max_iter=100)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.9

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
noise, noise_labels = make_blobs(n_samples=2, centers=[[20, 1]])
x_train = np.append(x_train, noise, axis=0)
true_labels = np.append(true_labels, noise_labels)
x_train_scaled = StandardScaler().fit_transform(x_train)

# %%
px.scatter(x=x_train_scaled[:, 0], y=x_train_scaled[:, 1], color=true_labels)

# %%
gmm = StandardGaussianMixture(n_components=n_clusters)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.6666666666666666

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
gmm = SpearmanGaussianMixture(n_components=n_clusters, max_iter=100, reg_covar=1e-3)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.6568627450980392

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
gmm = MADSpearmanGaussianMixture(n_components=n_clusters, max_iter=100)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.6274509803921569

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
gmm = MADOrtizGaussianMixture(n_components=n_clusters, max_iter=100, reg_covar=1e-2)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.6666666666666666

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)

# %%
gmm = MADApproxOrtizGaussianMixture(n_components=n_clusters, max_iter=100, reg_covar=1e-2)
gmm.fit(x_train_scaled)
gmm.accuracy_score(x_train_scaled, true_labels)
# Out:
# 0.6666666666666666

# %%
plot_gaussian_mixtures(gmm, x_train_scaled)
